# %% [markdown]
# This code uses the V1 version of OANDA API.
# It will be stoped by the firm but it is good to understands

# %%
import v20
import json

# %%
import requests

# %%
response = requests.get("https://api-fxpractice.oanda.com/v3/candles?instrument=EUR_USD&count=2")

# %%
response.status_code
# Out:
# 405

# %%
response.content
# Out:
# b'{\n    "code" : 38,\n    "message" : "No matching handler for the request is found",\n    "moreInfo" : "http:\\/\\/developer.oanda.com\\/docs\\/v1\\/troubleshooting\\/#errors"\n}\n\n'

# %%
params = {
    "instrument": 'EUR_USD',
    "count": 20,
    "granularity": 'H1'
}

# %%
response = requests.get("https://api-fxtrade.oanda.com/v1/candles", params=params)
response.content
#https://api-fxpractice.oanda.com
#https://api-fxtrade.oanda.com
# Out:
# b'{\n\t"instrument" : "EUR_USD",\n\t"granularity" : "H1",\n\t"candles" : [\n\t\t{\n\t\t\t"time" : "2020-05-01T01:00:00.000000Z",\n\t\t\t"openBid" : 1.09451,\n\t\t\t"openAsk" : 1.0947,\n\t\t\t"highBid" : 1.09461,\n\t\t\t"highAsk" : 1.09477,\n\t\t\t"lowBid" : 1.09359,\n\t\t\t"lowAsk" : 1.09374,\n\t\t\t"closeBid" : 1.09414,\n\t\t\t"closeAsk" : 1.0943,\n\t\t\t"volume" : 1725,\n\t\t\t"complete" : true\n\t\t},\n\t\t{\n\t\t\t"time" : "2020-05-01T02:00:00.000000Z",\n\t\t\t"openBid" : 1.09412,\n\t\t\t"openAsk" : 1.09429,\n\t\t\t"highBid" : 1.09458,\n\t\t\t"highAsk" : 1.09473,\n\t\t\t"lowBid" : 1.09374,\n\t\t\t"lowAsk" : 1.09391,\n\t\t\t"closeBid" : 1.0944,\n\t\t\t"closeAsk" : 1.09457,\n\t\t\t"volume" : 1192,\n\t\t\t"complete" : true\n\t\t},\n\t\t{\n\t\t\t"time" : "2020-05-01T03:00:00.000000Z",\n\t\t\t"openBid" : 1.09439,\n\t\t\t"openAsk" : 1.09455,\n\t\t\t"highBid" : 1.09456,\n\t\t\t"highAsk" : 1.09471,\n\t\t\t"lowBid" : 1.09397,\n\t\t\t"lowAsk" : 1.09415,\n\t\t\t"closeBid" : 1.09445,\n\t\t\t
# ...

# %%
json_data = response.json()

# %%
json_data
# Out:
# {'instrument': 'EUR_USD',
#  'granularity': 'H1',
#  'candles': [{'time': '2020-05-01T01:00:00.000000Z',
#    'openBid': 1.09451,
#    'openAsk': 1.09471,
#    'highBid': 1.0946,
#    'highAsk': 1.09477,
#    'lowBid': 1.0936,
#    'lowAsk': 1.09375,
#    'closeBid': 1.09414,
#    'closeAsk': 1.0943,
#    'volume': 1730,
#    'complete': True},
#   {'time': '2020-05-01T02:00:00.000000Z',
#    'openBid': 1.09412,
#    'openAsk': 1.09429,
#    'highBid': 1.09458,
#    'highAsk': 1.09472,
#    'lowBid': 1.09373,
#    'lowAsk': 1.0939,
#    'closeBid': 1.0944,
#    'closeAsk': 1.09456,
#    'volume': 1165,
#    'complete': True},
#   {'time': '2020-05-01T03:00:00.000000Z',
#    'openBid': 1.09438,
#    'openAsk': 1.09454,
#    'highBid': 1.09456,
#    'highAsk': 1.09471,
#    'lowBid': 1.09398,
#    'lowAsk': 1.09415,
#    'closeBid': 1.09445,
#    'closeAsk': 1.09459,
#    'volume': 915,
#    'complete': True},
#   {'time': '2020-05-01T04:00:00.000000Z',
#    'openBid': 1.09443,
# ...

# %%
json_data
# Out:
# {'instrument': 'EUR_USD',
#  'granularity': 'H1',
#  'candles': [{'time': '2020-05-01T01:00:00.000000Z',
#    'openBid': 1.09451,
#    'openAsk': 1.0947,
#    'highBid': 1.09461,
#    'highAsk': 1.09477,
#    'lowBid': 1.09359,
#    'lowAsk': 1.09374,
#    'closeBid': 1.09414,
#    'closeAsk': 1.0943,
#    'volume': 1725,
#    'complete': True},
#   {'time': '2020-05-01T02:00:00.000000Z',
#    'openBid': 1.09412,
#    'openAsk': 1.09429,
#    'highBid': 1.09458,
#    'highAsk': 1.09473,
#    'lowBid': 1.09374,
#    'lowAsk': 1.09391,
#    'closeBid': 1.0944,
#    'closeAsk': 1.09457,
#    'volume': 1192,
#    'complete': True},
#   {'time': '2020-05-01T03:00:00.000000Z',
#    'openBid': 1.09439,
#    'openAsk': 1.09455,
#    'highBid': 1.09456,
#    'highAsk': 1.09471,
#    'lowBid': 1.09397,
#    'lowAsk': 1.09415,
#    'closeBid': 1.09445,
#    'closeAsk': 1.09459,
#    'volume': 908,
#    'complete': True},
#   {'time': '2020-05-01T04:00:00.000000Z',
#    'openBid': 1.09443,
# ...

# %%
json_data
# Out:
# {'instrument': 'EUR_USD',
#  'granularity': 'H1',
#  'candles': [{'time': '2020-05-01T01:00:00.000000Z',
#    'openBid': 1.09451,
#    'openAsk': 1.0947,
#    'highBid': 1.09461,
#    'highAsk': 1.09477,
#    'lowBid': 1.09359,
#    'lowAsk': 1.09374,
#    'closeBid': 1.09414,
#    'closeAsk': 1.0943,
#    'volume': 1725,
#    'complete': True},
#   {'time': '2020-05-01T02:00:00.000000Z',
#    'openBid': 1.09412,
#    'openAsk': 1.09429,
#    'highBid': 1.09458,
#    'highAsk': 1.09473,
#    'lowBid': 1.09374,
#    'lowAsk': 1.09391,
#    'closeBid': 1.0944,
#    'closeAsk': 1.09457,
#    'volume': 1192,
#    'complete': True},
#   {'time': '2020-05-01T03:00:00.000000Z',
#    'openBid': 1.09439,
#    'openAsk': 1.09455,
#    'highBid': 1.09456,
#    'highAsk': 1.09471,
#    'lowBid': 1.09397,
#    'lowAsk': 1.09415,
#    'closeBid': 1.09445,
#    'closeAsk': 1.09459,
#    'volume': 908,
#    'complete': True},
#   {'time': '2020-05-01T04:00:00.000000Z',
#    'openBid': 1.09443,
# ...
