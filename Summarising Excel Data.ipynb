# %%
import pandas as pd
import numpy as np

# %%
path = 'C:/Users/bearp/Documents/Forex_DB/'

# %%
Year = ['2011','2012','2013','2014','2015','2016','2017','2018','2019']
file_list = []
for i in Year:
    file_list.append('df_'+i)
print(file_list)

y = 0
for i in file_list:
    yr = Year[y]
    globals()[i]=pd.read_excel(path+'Annualof_'+yr+'.xls')
    y = y+1
# Out:
# ['df_2011', 'df_2012', 'df_2013', 'df_2014', 'df_2015', 'df_2016', 'df_2017', 'df_2018', 'df_2019']

# %%
df_2014.head()
# Out:
#             Market_and_Exchange_Names  As_of_Date_In_Form_YYMMDD  \
# 0  WHEAT-SRW - CHICAGO BOARD OF TRADE                     141230
# 1  WHEAT-SRW - CHICAGO BOARD OF TRADE                     141223
# 2  WHEAT-SRW - CHICAGO BOARD OF TRADE                     141216
# 3  WHEAT-SRW - CHICAGO BOARD OF TRADE                     141209
# 4  WHEAT-SRW - CHICAGO BOARD OF TRADE                     141202
#
#   Report_Date_as_MM_DD_YYYY CFTC_Contract_Market_Code CFTC_Market_Code  \
# 0                2014-12-30                    001602              CBT
# 1                2014-12-23                    001602              CBT
# 2                2014-12-16                    001602              CBT
# 3                2014-12-09                    001602              CBT
# 4                2014-12-02                    001602              CBT
#
#    CFTC_Region_Code  CFTC_Commodity_Code  Open_Interest_All  \
# 0                 0                    1             472346
# ...

# %%
df=pd.DataFrame()
for i in file_list:
    df = df.append(globals()[i], ignore_index=True)
    print(df.shape)
# Out:
# (7659, 126)
# (15677, 126)
# (26260, 126)
# (38842, 126)
# (50940, 126)
# (63764, 126)
# (76525, 126)
# (90295, 126)
# (104051, 126)

# %%
df_a = df.loc[:,:'NonRept_Positions_Short_Other']

# %%
USD_index = df[df['Market_and_Exchange_Names'] == 'U.S. DOLLAR INDEX - ICE FUTURES U.S.']

# %%
# Put the Date as Index
USD_index['Date']=USD_index.loc[:,'Report_Date_as_MM_DD_YYYY'].copy()
USD_index=USD_index.set_index('Date').sort_index(ascending=True)
USD_index.head()
# Out:
# C:\Users\bearp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Market_and_Exchange_Names  As_of_Date_In_Form_YYMMDD  \
# Date
# 2011-01-04  U.S. DOLLAR INDEX - ICE FUTURES U.S.                     110104
# 2011-01-11  U.S. DOLLAR INDEX - ICE FUTURES U.S.                     110111
# 2011-01-18  U.S. DOLLAR INDEX - ICE FUTURES U.S.                     110118
# 2011-01-25  U.S. DOLLAR INDEX - ICE FUTURES U.S.                     110125
# 2011-02-01  U.S. DOLLAR INDEX - ICE FUTURES U.S.                     110201
#
#            Report_Date_as_MM_DD_YYYY CFTC_Contract_Market_Code  \
# Date
# 2011-01-04                2011-01-04                    098662
# ...

# %%
df_market = df.groupby('Market_and_Exchange_Names')
df_market.head()
# Out:
#                            Market_and_Exchange_Names  \
# 0      CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 1      CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 2      CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 3      CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 4      CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# ...                                              ...
# 12435      5 YEAR ERIS SWAP - CHICAGO BOARD OF TRADE
# 12436      5 YEAR ERIS SWAP - CHICAGO BOARD OF TRADE
# 12437      5 YEAR ERIS SWAP - CHICAGO BOARD OF TRADE
# 12438      5 YEAR ERIS SWAP - CHICAGO BOARD OF TRADE
# 12439      5 YEAR ERIS SWAP - CHICAGO BOARD OF TRADE
#
#        As_of_Date_In_Form_YYMMDD Report_Date_as_MM_DD_YYYY  \
# 0                         141230                2014-12-30
# 1                         141223                2014-12-23
# 2                         141216                2014-12-16
# 3                         141209                2014-12-09
# ...

# %%
Market = df.Market_and_Exchange_Names.drop_duplicates()
print(Market)
# Out:
# 0            CANADIAN DOLLAR - CHICAGO MERCANTILE EXCHANGE
# 52               SWISS FRANC - CHICAGO MERCANTILE EXCHANGE
# 104      BRITISH POUND STERLING - CHICAGO MERCANTILE EX...
# 156             JAPANESE YEN - CHICAGO MERCANTILE EXCHANGE
# 208                  EURO FX - CHICAGO MERCANTILE EXCHANGE
#                                ...
# 9959        5 YEAR DELIVERABLE IR - CHICAGO BOARD OF TRADE
# 10012    5-Year Eris Standard- Initial - ERIS FUTURES E...
# 10073                BITCOIN - CHICAGO MERCANTILE EXCHANGE
# 12433          10 YEAR ERIS SWAP  - CHICAGO BOARD OF TRADE
# 12435            5 YEAR ERIS SWAP - CHICAGO BOARD OF TRADE
# Name: Market_and_Exchange_Names, Length: 71, dtype: object

# %%
df_a.to_excel('total_a.xlsx')

# %%
NonRept_Positions_Short_Other
